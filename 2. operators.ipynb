# %% [markdown]
# # Operators

# %% [markdown]
# # 1. Arithmetic operator

# %%
a=680
b=560
print("A+B=",a+b)
print("A-B=", a-b)
print("A*B=",a*b)
print("A/B=",a+b)
print("A%B=",a%b)
# Out:
# A+B= 1240
# A-B= 120
# A*B= 380800
# A/B= 1240
# A%B= 120

# %% [markdown]
# # 2. Comparison operator

# %%
a=56
b=78
print("A>B=",a>b)
print("A<B=", a<b)
print("A==B",a==b)
# Out:
# A>B= False
# A<B= True
# A==B False

# %% [markdown]
# # 3.logical operator

# %% [markdown]
# # 1. And

# %%
True and True and True
# Out:
# True

# %%
True and False and True
# Out:
# False

# %% [markdown]
# # 2. OR

# %%
True or True or False
# Out:
# True

# %% [markdown]
# # 3. Not

# %%
not False
# Out:
# True

# %%
n=20
print(n>15 or n>25)
# Out:
# True

# %%
x=78
y=78.78
z=72
avg=(x+y+z)/3
print("the average is ", avg)
# Out:
# the average is  76.26

# %% [markdown]
# # Sum of 2 Numbers

# %%
a=int(input("enter the value"))
b=int(input("enter the value"))
c=a+b
print("the sum is",c)
# Out:
# enter the value 89
# enter the value 89
# the sum is 178

# %% [markdown]
# # Subtraction of 2 number

# %%
a=int(input("enter the value"))
b-=int(input("enter the value"))
c=a-b
print("the subtraction is", c)
# Out:
# enter the value 90
# enter the value 98
# the subtraction is 99

# %% [markdown]
# # Simple interest

# %%
p=int(input("enter the principle"))
r=float(input("enter the rate"))
t=int(input("enter the time"))
si=p*r*t/100
print("the value is",si)
# Out:
# enter the principle 89
# enter the rate 6
# enter the time 6
# the value is 32.04

# %% [markdown]
# # Multiplication of 2 number

# %%
a=float(input("enter the value"))
b=float(input("enter the value"))
c=a*b
print("the value is", c)
# Out:
# enter the value 12
# enter the value 23
# the value is 276.0

# %% [markdown]
# # Average

# %%
x=float(input("enter the number"))
y=float(input("enter the number"))
z=float(input("enter the number"))
avg=(x+y+z)/3
print("the average is", avg)
# Out:
# enter the number 89
# enter the number 67
# enter the number 56
# the average is 70.66666666666667

# %% [markdown]
# # Percentage

# %%
e=float(input("enter the marks out of 100"))
h=float(input("enter the marks out of 100"))
m=float(input("enter the maarks out of 100"))
s=float(input("enter the marks out off 100"))
p=float(input("enter the marks out of 100"))
s=e+h+m+s+p
per=s*100/500
print("the percentage is", per)
# Out:
# enter the marks out of 100 78
# enter the marks out of 100 90
# enter the maarks out of 100 89
# enter the marks out off 100 67
# enter the marks out of 100 56
# the percentage is 76.0

# %% [markdown]
# # Square root of a number

# %%
b=float(input("enter the number"))
res=b**(1/2)
print(" square root of a number is",res)
# Out:
# enter the number 78
#  square root of a number is 8.831760866327848

# %% [markdown]
# # Another way of square root

# %%
n=float(input("enter the number"))
res=pow(n,(1/2))   #pow(a,b) a= number b=power
print(res)
# Out:
# enter the number 7
# 2.6457513110645907

# %% [markdown]
# # Comparison operator

# %%
a=int(input("enter the number"))
b-int(input("enter the number"))
print(a>b)
print(a<b)
print(a==b)
# Out:
# enter the number 8
# enter the number 7
# False
# True
# False

# %%
a= int(input("enter the number"))
b=float(input("enter thr number"))
c=a*b
print("multiplication value is", c)
# Out:
# enter the number 89
# enter thr number 56
# multiplication value is 4984.0
