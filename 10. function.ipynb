# %% [markdown]
# # Function

# %% [markdown]
# # Syntax

# %% [markdown]
# def function_name(): #defination
# logic
#
# function_name()# calling

# %%
def addition():
    a=int(input("enter the number"))
    b=int(input("enter the number"))
    c=a+b
    print("the sum is",c)

# %% [markdown]
# # Calling

# %%
addition()
# Out:
# enter the number 89
# enter the number 78
# the sum is 167

# %% [markdown]
# we can call it multiple times

# %%
addition()
# Out:
# enter the number 89
# enter the number 56
# the sum is 145

# %%
def interest():
    p=int(input("enter the principle"))
    r=float(input("enter the number"))
    t=int(input("enter the time"))
    si=p*r*t/100
    print("the simple interest is",si)

# %% [markdown]
# # Simple Interest

# %%
interest()
# Out:
# enter the principle 89
# enter the number 89.09
# enter the time 8
# the simple interest is 634.3208

# %% [markdown]
#  # Average

# %%
def average():
    a=int(input("enter the number"))
    b=int(input("enter the number"))
    c=int(input("enter the number"))
    avg=(a+b+c)/3
    print("the average is",avg)

# %%
average()
# Out:
# enter the number 78
# enter the number 90
# enter the number 90
# the average is 86.0

# %% [markdown]
# # percentage

# %%
def percentage():
    e=int(input("enter the marks out of 100"))
    h=int(input("enter the marks out of 100"))
    m=int(input("enter the marks out of 100"))
    s=int(input("enter the marks out of 100"))
    c=int(input("enter the marks out of 100"))
    s=e+h+m+s+c
    per=s*100/500
    print("the percentage is",per)

# %%
percentage()
# Out:
# enter the marks out of 100 90
# enter the marks out of 100 90
# enter the marks out of 100 90
# enter the marks out of 100 90
# enter the marks out of 100 90
# the percentage is 90.0

# %% [markdown]
# # Check

# %%
def check():
    a=int(input("enter the number"))
    if a%2==0:
        print("even number")
    else:
        print("odd number")

# %%
check()
# Out:
# enter the number 90
# even number

# %% [markdown]
# # Leap Year

# %%
def leapyear():
    a=int(input("enter the year"))
    if a%4==0:
        print("leap year")
    else:
        print("nott a leap year")

# %%
leapyear()
# Out:
# enter the year 1999
# nott a leap year

# %% [markdown]
# # Vote Eligibility

# %%
def vote_eligibility():
    age=int(input("enter the age"))
    if age>=18:
        print("eligible to vote")
    else:
        print("not eligible")

# %%
vote_eligibility()
# Out:
# enter the age 89
# eligible to vote

# %% [markdown]
# # Argument function

# %% [markdown]
# # Syntax

# %% [markdown]
# def function_name(arg1,arg2..):
#
# logic
#
# function_name() --calling

# %% [markdown]
# # Addition

# %%
def addition(a,b):
    c=a+b
    print("the sum is",c)

# %%
addition(67,90)
# Out:
# the sum is 157

# %% [markdown]
# # Subtraction

# %%
def subtraction(a,b):
    c=a-b
    print("the sub is",c)

# %%
subtraction(89,90)
# Out:
# the sub is -1

# %% [markdown]
# # Interest

# %%
def interest (p,r,t):
    si=p*r*t/100
    print("the interest is",si)

# %%
interest(12,56.89,9)
# Out:
# the interest is 61.44120000000001

# %% [markdown]
# # Average

# %%
def average(x,y,z):
    avg=(x+y+z)/3
    print("the average is",avg)

# %%
average(90,89,78)
# Out:
# the average is 85.66666666666667

# %% [markdown]
# # Check

# %%
def check(n):
    if n%2==0:
        print("even number")
    else:
        print("odd number")

# %%
check(9)
# Out:
# odd number

# %% [markdown]
# # Leap Year

# %%
def leap_year(year):
    if year%4==0:
        print("leap year")
    else:
        print("not a leap year")

# %%
leap_year(2007)
# Out:
# not a leap year

# %% [markdown]
# # Vote Eligibility

# %%
def age(age):
    if age>=18:
        print("eligible to vote")
    else:
        print("not eligible")

# %%
age(7)
# Out:
# not eligible

# %% [markdown]
# # Return type

# %% [markdown]
#  # 1st method

# %%
def addition(a,b):
    return a+b

# %%
c=addition(98,56)
print(c)
# Out:
# 154

# %% [markdown]
# # 2nd method

# %%
print(addition(34,78))
# Out:
# 112

# %% [markdown]
# # 3rd method

# %%
addition(56,90)
# Out:
# 146

# %%
def interset(p,r,t):
    return p*r*t/100

si=interset(700,9.7,5)
print(si)
# Out:
# 339.49999999999994

# %% [markdown]
# # Placeholder argument

# %%
def addition(a,b=500,c=600):
    return a+b+c
print(addition(500))
print(addition(800,780))
print(addition(10,20,30))
# Out:
# 1600
# 2180
# 60

# %%
def addition(a,b=500,c=600):
    return a+b+c
print(addition(500))
print(addition(a=800,c=780))
print(addition(10,20,30))
# Out:
# 1600
# 2080
# 60

# %%
def datascience(a,b,c,d,e):
    return(a+b,a*b)

# %%
datascience(2,3,4,5,6)
# Out:
# (5, 6)

# %%
def hello(a,b):
    return("my name is {} and gender is {}".format(a,b))

# %%
hello("nidhi","female")
# Out:
# 'my name is nidhi and gender is female'

# %%
def hello(name,age=19,gender="female"):
    return("my name is {} and age is{} and gender is{}".format(name,age,gender))

# %%
hello("nidhi")
# Out:
# 'my name is nidhi and age is19 and gender isfemale'

# %%
def hello(name,age=19,gender="female"):
    return("my name is {} and age is {} and gender is {}".format(age,gender,name))

# %%
hello("nidhi")
# Out:
# 'my name is 19 and age is female and gender is nidhi'

# %% [markdown]
#  # Some mcq practice question

# %%
#mcq random
x=[1,2,3];
print(type(x)==list)
# Out:
# True

# %%
x=["XX","YY"]
y=[]
for i in x:
    y.append(i.lower())
print(x)
print(y)
# Out:
# ['XX', 'YY']
# ['xx', 'yy']

# %%
a=75 #global variable
def test_var():#local variable
    return a
print(test_var())
# Out:
# 75

# %%
0.2+0.3==0.5
# Out:
# True

# %%
def x(values):
    values[0]=33
v=[1,2,3]
x(v)
print(v)
# Out:
# [33, 2, 3]

# %%
list1=[1,2,3,4,5,6,7]
list1[:-1]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
m=[4,5,7,2,3]
m[1:2]=[8,9]
print(m)
# Out:
# [4, 8, 9, 7, 2, 3]

# %%
x=y=[2,3,4]
y[2]=5
print(x)
# Out:
# [2, 3, 5]

# %%
x=[12,34,89]
y=x.copy()
y is x #is compare on the basis on address
# Out:
# False

# %%
p1=(2,3,5,4)
p2=(2,3,4,5)
p1<p2
# Out:
# False

# %%
F={1:"x",2:"y",3:"z"}
print(F.get(8,"not found"))
# Out:
# not found
