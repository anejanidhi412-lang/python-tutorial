# %% [markdown]
# # Dictionary

# %%
n1={"name":"nidhi","age":20,"city":"delhi"}
n1
# Out:
# {'name': 'nidhi', 'age': 20, 'city': 'delhi'}

# %%
d1={1:"one",2:"two",3:"three"}
d1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
d2={1.5:"one and half",2.5:"two and half"}
d2
# Out:
# {1.5: 'one and half', 2.5: 'two and half'}

# %%
d4={"sports":("cricket,hockey")}
d4
# Out:
# {'sports': 'cricket,hockey'}

# %%
d5={("learning","travelling"):"hobbies"}
d5
# Out:
# {('learning', 'travelling'): 'hobbies'}

# %%
d6={"name":"nidhi","age":20,"city":"delhi"}
d6
# Out:
# {'name': 'nidhi', 'age': 20, 'city': 'delhi'}

# %%
d6["name"]
# Out:
# 'nidhi'

# %% [markdown]
# # Methods of Dictionary

# %% [markdown]
# # 1. Get method

# %%
d7={"name":"nidhi","age":20,"city":"delhi"}
d7
# Out:
# {'name': 'nidhi', 'age': 20, 'city': 'delhi'}

# %%
d7.get("name")
# Out:
# 'nidhi'

# %%
print(d7.get("address"))
# Out:
# None

# %%
d5={"name":"nidhi","age":20,"name":"himanshu"}
d5
# Out:
# {'name': 'himanshu', 'age': 20}

# %% [markdown]
# # 2. Updation

# %%
d5={"india":"dhoni","england":"root"}
d5
# Out:
# {'india': 'dhoni', 'england': 'root'}

# %% [markdown]
# # 3. Del

# %%
del d5["india"]
d5
# Out:
# {'england': 'root'}

# %%
del d5["india"]
d5
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 del d5["india"]
#       2 d5
#
# KeyError: 'india'

# %%
d5={"india":"dhoni","england":"root"}
print(d5)
print("value is being deleated",d5.pop("india"))
print(d5)
# Out:
# {'india': 'dhoni', 'england': 'root'}
# value is being deleated dhoni
# {'england': 'root'}

# %%
d5={"india":"dhoni","england":"root"}
print(d5)
d5.popitem()
print(d5)
d5.popitem()
print(d5)
# Out:
# {'india': 'dhoni', 'england': 'root'}
# {'india': 'dhoni'}
# {}

# %% [markdown]
# # Keys

# %%
d7={"name":"nidhi","age":20,"city":"delhi"}
d7.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %% [markdown]
# # Value

# %%
d7={"name":"nidhi","age":20,"city":"delhi"}
d7.values()
# Out:
# dict_values(['nidhi', 20, 'delhi'])

# %% [markdown]
# # Items

# %%
d4=={"name":"nidhi","age":20,"course":"ds"}
d4.items()
# Out:
# dict_items([('sports', 'cricket,hockey')])

# %% [markdown]
# # 4. Clear

# %%
d4={"name":"nidhi","age":30,"course":"ds"}
d4.clear()
d4
# Out:
# {}

# %% [markdown]
# # 5. Fromkeys

# %%
key=["red","green","yellow","orange"]
value="color"
x=dict.fromkeys(key,value)
x
# Out:
# {'red': 'color', 'green': 'color', 'yellow': 'color', 'orange': 'color'}

# %%
key=["nidhi","himanshu","parth"]
x=dict.fromkeys(key)
x
# Out:
# {'nidhi': None, 'himanshu': None, 'parth': None}

# %% [markdown]
# # 6. Update

# %%
#update
x={1:"one",3:"three",5:"five"}
y={2:"two",4:"four",6:"six"}
y.update(x)
y
# Out:
# {2: 'two', 4: 'four', 6: 'six', 1: 'one', 3: 'three', 5: 'five'}

# %% [markdown]
# # Dictionary membership

# %%
n={"name":"nidhi","id":1234,"dob":2007,"job":"ds"}
n
# Out:
# {'name': 'nidhi', 'id': 1234, 'dob': 2007, 'job': 'ds'}

# %%
"name" in n
# Out:
# True

# %%
"gender" in n
# Out:
# False

# %% [markdown]
# # 7. All

# %%
n={"name":"nidhi","id":1234,"dob":2007,0:"ds"}
n
all(n)
# Out:
# False

# %% [markdown]
# # 8. Any

# %%
n={"name":"nidhi","id":1234,"dob":2007,0:"ds"}
n
any(n)
# Out:
# True
