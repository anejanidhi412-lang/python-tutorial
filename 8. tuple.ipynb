# %% [markdown]
# # Tuple

# %%
n=(12,34,65,89)
n
# Out:
# (12, 34, 65, 89)

# %%
n=(12.45,79.67,67,8)
n
# Out:
# (12.45, 79.67, 67, 8)

# %%
n=("nidhi","himanshu","parth")
n
# Out:
# ('nidhi', 'himanshu', 'parth')

# %%
x=90,67,89
type(x)
# Out:
# tuple

# %%
a=tuple("nidhi")
a
# Out:
# ('n', 'i', 'd', 'h', 'i')

# %%
x=tuple([12,3,45,67])
x
# Out:
# (12, 3, 45, 67)

# %%
t1=(56)
type(t1)
# Out:
# int

# %%
t1=(56,)
type(t1)
# Out:
# tuple

# %%
t1=(12,34,5678,90,55)
print(t1[4])
print(t1[4])
print(t1[-4])
# Out:
# 55
# 55
# 34

# %%
t1=(12,34,56,78,90,87,65)
t1[2:-2]
# Out:
# (56, 78, 90)

# %%
t1=(12,34,56,78,90,87,65)
t1[3]="nidhi"
t1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 t1=(12,34,56,78,90,87,65)
# ----> 2 t1[3]="nidhi"
#       3 t1
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1=(12,34,56,78,90,87,65)
x=list(t1)
x[3]="nidhi"
t1=tuple(x)
t1
# Out:
# (12, 34, 56, 'nidhi', 90, 87, 65)

# %% [markdown]
# # Tuple Methods

# %% [markdown]
# # Count

# %%
t1=(12,34,56,78,90,87,65,65)
t1.count(65)
# Out:
# 2

# %% [markdown]
# # Index

# %%
t1=(12,34,56,78,90,87,65,65)
t1.index(65)
# Out:
# 6
